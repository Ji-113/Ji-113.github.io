# %% [markdown]
# <a href="https://colab.research.google.com/github/Ji-113/Ji-113.github.io/blob/main/Python%E3%82%B2%E3%83%BC%E3%83%A0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("俺はN大和学園からの刺客KKだ。今日は某T大寺学園に潜入し、全員始末する計画を実行する。")
import random
生徒1=2000
生徒2=3000
生徒3=4000
副生徒会長=7000
生徒会長=8000
先生1=15000
先生2=16000
先生3=17000
中1学年主任=20000
中2学年主任=21000
中3学年主任=22000
高1学年主任=23000
高2学年主任=24000
高3学年主任=25000
国語教科主任=26000
数学教科主任=27000
英語教科主任=28000
教頭=35000
校長=40000
HP=0
T=random.randint(1,19)
if T == 1:
  print("T大寺学園の生徒Aが現れた!!!")
  HP=生徒1
elif T == 2:
   print("T大寺学園の生徒Bが現れた!!!")
   HP=生徒2
elif T ==3:
  print("T大寺学園の生徒Cが現れた!!!")
  HP=生徒3
elif T == 4:
  print("T大寺学園の副生徒会長が現れた!!!")
  HP=副生徒会長
elif T == 5:
  print("T大寺学園の生徒会長が現れた!!!")
  HP=生徒会長
elif T == 6:
  print("T大寺学園の先生Aが現れた!!!")
  HP=先生1
elif T == 7:
  print("T大寺学園の先生Bが現れた!!!")
  HP=先生2
elif T == 8:
  print("T大寺学園の先生Cが現れた!!!")
  HP=先生3
elif T == 9:
  print("T大寺学園の中1学年主任が現れた!!!")
  HP=中1学年主任
elif T == 10:
  print("T大寺学園の中2学年主任が現れた!!!")
  HP=中2学年主任
elif T == 11:
  print("T大寺学園の中3学年主任が現れた!!!")
  HP=中3学年主任
elif T == 12:
  print("T大寺学園の高1学年主任が現れた!!!")
  HP=高1学年主任
elif T == 13:
  print("T大寺学園の高2学年主任が現れた!!!")
  HP=高2学年主任
elif T == 14:
  print("T大寺学園の高3学年主任が現れた!!!")
  HP=高3学年主任
elif T == 15:
  print("T大寺学園の国語の教科主任が現れた!!!")
  HP=国語教科主任
elif T == 16:
  print("T大寺学園の数学の教科主任が現れた!!!")
  HP=数学教科主任
elif T == 17:
  print("T大寺学園の英語の教科主任が現れた!!!")
  HP=英語教科主任
elif T == 18:
  print("T大寺学園の教頭が現れた!!!")
  HP=教頭
elif T == 19:
  print("T大寺学園の校長が現れた!!!")
  HP=校長
while HP > 0:
  select=int(input("1.発砲する(30%の確率で成功) 　　2.殴りかかる(95%の確率で成功)　　 3.N大和学園へ戻る(50%の確率で成功)"))
  if select == 1:
    attack=random.randint(1,100)
    if attack <= 70:
      print("外れた!!!")
      print("どうしますか？")
    else:
      damage1=random.randint(1000,1500)
      if T==1:
        HP-=damage1
        print("生徒Aに",damage1,"点ダメージを与えました。")
      elif T==2:
        HP-=damage1
        print("生徒Bに",damage1,"点ダメージを与えました。")
      elif T==3:
        HP-=damage1
        print("生徒Cに",damage1,"点ダメージを与えました。")
      elif T==4:
        HP-=damage1
        print("副生徒会長に",damage1,"点ダメージを与えました。")
      elif T==5:
        HP-=damage1
        print("生徒会長に",damage1,"点ダメージを与えました。")
      elif T==6:
        HP-=damage1
        print("先生Aに",damage1,"点ダメージを与えました。")
      elif T==7:
        HP-=damage1
        print("先生Bに",damage1,"点ダメージを与えました。")
      elif T==8:
        HP-=damage1
        print("先生Cに",damage1,"点ダメージを与えました。")
      elif T==9:
        HP-=damage1
        print("中1学年主任に",damage1,"点ダメージを与えました。")
      elif T==10:
        HP-=damage1
        print("中2学年主任に",damage1,"点ダメージを与えました。")
      elif T==11:
        HP-=damage1
        print("中3学年主任に",damage1,"点ダメージを与えました。")
      elif T==12:
        HP-=damage1
        print("高1学年主任に",damage1,"点ダメージを与えました。")
      elif T==13:
        HP-=damage1
        print("高2学年主任に",damage1,"点ダメージを与えました。")
      elif T==14:
        HP-=damage1
        print("高3学年主任に",damage1,"点ダメージを与えました。")
      elif T==15:
        HP-=damage1
        print("国語の教科主任に",damage1,"点ダメージを与えました。")
      elif T==16:
        HP-=damage1
        print("数学の教科主任に",damage1,"点ダメージを与えました。")
      elif T==17:
        HP-=damage1
        print("英語の教科主任に",damage1,"点ダメージを与えました。")
      elif T==18:
        HP-=damage1
        print("教頭に",damage1,"点ダメージを与えました。")
      elif T==19:
        HP-=damage1
        print("校長に",damage1,"点ダメージを与えました。")
      if 0 < HP:
        print("残りHP:",HP)
      if HP <= 0:
        continue
      print("どうしますか？")
  elif select == 2:
    attack=random.randint(1,100)
    if attack <= 5:
      print("空振り!!!")
      print("どうしますか？")
    else:
      damage2=random.randint(100,300)
      if T==1:
        HP-=damage2
        print("生徒Aに",damage2,"点ダメージを与えました。")
      elif T==2:
        HP-=damage2
        print("生徒Bに",damage2,"点ダメージを与えました。")
      elif T==3:
        HP-=damage2
        print("生徒Cに",damage2,"点ダメージを与えました。")
      elif T==4:
        HP-=damage2
        print("副生徒会長に",damage2,"点ダメージを与えました。")
      elif T==5:
        HP-=damage2
        print("生徒会長に",damage2,"点ダメージを与えました。")
      elif T==6:
        HP-=damage211
        print("先生Aに",damage2,"点ダメージを与えました。")
      elif T==7:
        HP-=damage2
        print("先生Bに",damage2,"点ダメージを与えました。")
      elif T==8:
        HP-=damage2
        print("先生Cに",damage2,"点ダメージを与えました。")
      elif T==9:
        HP-=damage2
        print("中1学年主任に",damage2,"点ダメージを与えました。")
      elif T==10:
        HP-=damage2
        print("中2学年主任に",damage2,"点ダメージを与えました。")
      elif T==11:
        HP-=damage2
        print("中3学年主任に",damage2,"点ダメージを与えました。")
      elif T==12:
        HP-=damage2
        print("高1学年主任に",damage2,"点ダメージを与えました。")
      elif T==13:
        HP-=damage2
        print("高2学年主任に",damage2,"点ダメージを与えました。")
      elif T==14:
        HP-=damage2
        print("高3学年主任に",damage2,"点ダメージを与えました。")
      elif T==15:
        HP-=damage2
        print("国語の教科主任に",damage2,"点ダメージを与えました。")
      elif T==16:
        HP-=damage2
        print("数学の教科主任に",damage2,"点ダメージを与えました。")
      elif T==17:
        HP-=damage2
        print("英語の教科主任に",damage2,"点ダメージを与えました。")
      elif T==18:
        HP-=damage2
        print("教頭に",damage2,"点ダメージを与えました。")
      elif T==19:
        HP-=damage2
        print("校長に",damage2,"点ダメージを与えました。")
      if 0 < HP:
        print("残りHP:",HP)
      if HP <= 0:
        continue
      print("どうしますか？")
  elif select == 37:
    attack=random.randint(1,100)
    if attack <= 0:
      print("空振り!!!")
      print("どうしますか？")
    else:
      damage37=random.randint(10000000000000000000000000000,10000000000000000000000000001)
      if T==1:
        HP-=damage37
        print("なんとKKの彼女あや◯が現れ、KKに力を与えた！！そして、生徒Aに",damage37,"点ダメージを与えた！")
      elif T==2:
        HP-=damage37
        print("なんとKKの彼女あや◯が現れ、KKに力を与えた！！そして、生徒Bに",damage37,"点ダメージを与えた！")
      elif T==3:
        HP-=damage37
        print("なんとKKの彼女あや◯が現れ、KKに力を与えた！！そして、生徒Cに",damage37,"点ダメージを与えた！")
      elif T==4:
        HP-=damage37
        print("なんとKKの彼女あや◯が現れ、KKに力を与えた！！そして、副生徒会長に",damage37,"点ダメージを与えた！")
      elif T==5:
        HP-=damage37
        print("なんとKKの彼女あや◯が現れ、KKに力を与えた！！そして、生徒会長に",damage37,"点ダメージを与えた！")
      elif T==6:
        HP-=damage37
        print("なんとKKの彼女あや◯が現れ、KKに力を与えた！！そして、先生Aに",damage37,"点ダメージを与えた！")
      elif T==7:
        HP-=damage37
        print("なんとKKの彼女あや◯が現れ、KKに力を与えた！！そして、先生Bに",damage37,"点ダメージを与えた！")
      elif T==8:
        HP-=damage37
        print("なんとKKの彼女あや◯が現れ、KKに力を与えた！！そして、先生Cに",damage37,"点ダメージを与えた！")
      elif T==9:
        HP-=damage37
        print("なんとKKの彼女あや◯が現れ、KKに力を与えた！！そして、中1学年主任に",damage37,"点ダメージを与えた！")
      elif T==10:
        HP-=damage37
        print("なんとKKの彼女あや◯が現れ、KKに力を与えた！！そして、中2学年主任に",damage37,"点ダメージを与えた！")
      elif T==11:
        HP-=damage37
        print("なんとKKの彼女あや◯が現れ、KKに力を与えた！！そして、中3学年主任に",damage3,"点ダメージを与えた！")
      elif T==12:
        HP-=damage37
        print("なんとKKの彼女あや◯が現れ、KKに力を与えた！！そして、高1学年主任に",damage37,"点ダメージを与えた！")
      elif T==13:
        HP-=damage37
        print("なんとKKの彼女あや◯が現れ、KKに力を与えた！！そして、高2学年主任に",damage37,"点ダメージを与えた！")
      elif T==14:
        HP-=damage37
        print("なんとKKの彼女あや◯が現れ、KKに力を与えた！！そして、高3学年主任に",damage37,"点ダメージを与えた！")
      elif T==15:
        HP-=damage37
        print("なんとKKの彼女あや◯が現れ、KKに力を与えた！！そして、国語の教科主任に",damage37,"点ダメージを与えた！")
      elif T==16:
        HP-=damage37
        print("なんとKKの彼女あや◯が現れ、KKに力を与えた！！そして、数学の教科主任に",damage37,"点ダメージを与えた！")
      elif T==17:
        HP-=damage37
        print("なんとKKの彼女あや◯が現れ、KKに力を与えた！！そして、英語の教科主任に",damage37,"点ダメージを与えた！")
      elif T==18:
        HP-=damage37
        print("なんとKKの彼女あや◯が現れ、KKに力を与えた！！そして、教頭に",damage37,"点ダメージを与えた！")
      elif T==19:
        HP-=damage37
        print("なんとKKの彼女あや◯が現れ、KKに力を与えた！！そして、校長に",damage37,"点ダメージを与えた！")
      if 0 < HP:
        print("残りHP:",HP)
      if HP <= 0:
        continue
      print("どうしますか？")
  elif select == 3:
    run_away=random.randint(1,2)
    if run_away==1:
      print("道が分からなかった！")
      print("どうしますか？")
    else:
      print("隙を見てN大和学園に戻ることが出来た！")
      break
else:
  print("始末しました！！！")
# Out:
# 俺はN大和学園からの刺客KKだ。今日は某T大寺学園に潜入し、全員始末する計画を実行する。
# T大寺学園の中2学年主任が現れた!!!
# 1.発砲する(30%の確率で成功) 　　2.殴りかかる(95%の確率で成功)　　 3.N大和学園へ戻る(50%の確率で成功)37
# なんとKKの彼女あや◯が現れ、KKに力を与えた！！そして、中2学年主任に 10000000000000000000000000001 点ダメージを与えた！
# 始末しました！！！
